# %%
from main import get_json_datafile, URL, draw_plots


get_json_datafile(url=URL)
# Out:
# True

# %%
draw_plots("test_1.png", first_index=100, last_index=500, columns=["min", "max", "m"])
# Out:
# Файл new.png будет перезаписан!
# 'F:\\my_story\\pot\\test_12_05_2024\\plots'

# %%
draw_plots("test_2.png")
# Out:
# 'F:\\my_story\\pot\\test_12_05_2024\\plots'

# %%
draw_plots("test_2.png", first_index=100, last_index=200, columns=["ceiling_mean"])
# Out:
# Файл test_2.png будет перезаписан!
# 'F:\\my_story\\pot\\test_12_05_2024\\plots'
