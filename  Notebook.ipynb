# %%
from main import get_json_datafile, URL, draw_plots


get_json_datafile(url=URL)
# Out:
# True

# %%
# %%timeit 
draw_plots("test_1.png", first_index=100, last_index=500, columns=["min", "max", "m"])
# Out:
# 342 ms ± 108 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit draw_plots("test_2.png")
# Out:
# 581 ms ± 192 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit draw_plots("test_2.png", first_index=100, last_index=150, columns=["ceiling_mean"])
# Out:
# 104 ms ± 11.1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %load_ext line_profiler
# %lprun -f draw_plots draw_plots("test_2.png", first_index=100, last_index=150, columns=["ceiling_mean"])
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
# Timer unit: 1e-07 s
#
# Total time: 0.280131 s
# File: f:\my_story\pot\test_12_05_2024\main.py
# Function: draw_plots at line 99
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#     99                                           def draw_plots(
#    100                                               file_name: Annotated[str, MinLen(5)],
#    101                                               first_index: Annotated[int, Ge(0)] | None = None,
#    102                                               last_index: Annotated[int, Gt(0)] | None = None,
#    103                                               columns: list[str] = [],
#    104                                           ) -> str:
#    105                                               """
#    106                                               filename: имя_файла.png,
# ...

# %%
# %load_ext memory_profiler

# %memit draw_plots("test_2.png", first_index=100, last_index=500, columns=["ceiling_mean"])
# Out:
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler
# peak memory: 156.91 MiB, increment: 3.16 MiB

# %%
# %mprun -f draw_plots draw_plots("test_2.png", first_index=100, last_index=500, columns=["ceiling_mean"])
# Out:
# Filename: f:\my_story\pot\test_12_05_2024\main.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# ...
#     99    157.8 MiB    157.8 MiB           1   def draw_plots(
#    100                                             file_name: Annotated[str, MinLen(5)],
#    101                                             first_index: Annotated[int, Ge(0)] | None = None,
#    102                                             last_index: Annotated[int, Gt(0)] | None = None,
#    103                                             columns: list[str] = [],
#    104                                         ) -> str:
#    105                                             """
#    106                                             filename: имя_файла.png,
#    107                                             first_index: первая строка выборки,
#    108                                             last_index: последняя строка выборки,
# ...
